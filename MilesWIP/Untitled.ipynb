# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dog_data = pd.read_csv('~\OneDrive\Desktop\Git_Repo\TeamShiba\TeamShiba\MilesWIP\dognition_data_aggregated_by_dogid-Copy1.csv')
dog_data
# Out:
# C:\Users\miles\AppData\Local\Temp\ipykernel_16796\2137363181.py:1: DtypeWarning: Columns (26,27,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   dog_data = pd.read_csv('~\OneDrive\Desktop\Git_Repo\TeamShiba\TeamShiba\MilesWIP\dognition_data_aggregated_by_dogid-Copy1.csv')
#                                      Dog ID  Total Tests Completed  \
# 0      fd27b272-7144-11e5-ba71-058fbc01cf0b                     21
# 1      fd27b5ba-7144-11e5-ba71-058fbc01cf0b                     20
# 2      fd27b6b4-7144-11e5-ba71-058fbc01cf0b                      2
# 3      fd27b79a-7144-11e5-ba71-058fbc01cf0b                     11
# 4      fd27b86c-7144-11e5-ba71-058fbc01cf0b                     31
# ...                                     ...                    ...
# 17981  fdc235e0-7144-11e5-ba71-058fbc01cf0b                      7
# 17982  fdc23a68-7144-11e5-ba71-058fbc01cf0b                      1
# ...

# %%
dog_data.describe()
# Out:
#        Total Tests Completed  Mean ITI (days)  Median ITI (days)  \
# count           17986.000000     1.671800e+04       16718.000000
# mean                9.807239     2.300726e+00           0.275986
# std                 7.799484     1.011768e+01           7.182127
# min                 1.000000     6.090000e-07           0.000000
# 25%                 4.000000     3.719136e-03           0.002998
# 50%                 7.000000     1.466368e-01           0.003895
# 75%                16.000000     1.226744e+00           0.005012
# max                45.000000     6.509563e+02         650.956262
#
#        Time diff between first and last game (days)  \
# count                                  17986.000000
# mean                                      25.140728
# std                                       75.788752
# min                                        0.000000
# 25%                                        0.009343
# 50%                                        0.724473
# ...

# %%
dog_data.head()
# Out:
#                                  Dog ID  Total Tests Completed  \
# 0  fd27b272-7144-11e5-ba71-058fbc01cf0b                     21
# 1  fd27b5ba-7144-11e5-ba71-058fbc01cf0b                     20
# 2  fd27b6b4-7144-11e5-ba71-058fbc01cf0b                      2
# 3  fd27b79a-7144-11e5-ba71-058fbc01cf0b                     11
# 4  fd27b86c-7144-11e5-ba71-058fbc01cf0b                     31
#
#    Mean ITI (days) Mean ITI (minutes)  Median ITI (days) Median ITI (minutes)  \
# 0        28.201076        40609.54917           0.004687          6.749999931
# 1         0.413307        595.1622807           0.005845          8.416666781
# 2         0.009132        13.15000009           0.009132          13.15000009
# 3        56.115179        80805.85833           0.004433          6.383333325
# 4         7.734254        11137.32611           0.000399          0.574999984
#
#    Time diff between first and last game (days)  \
# 0                                    564.021516
# ...

# %%
dog_data.tail()
# Out:
#                                      Dog ID  Total Tests Completed  \
# 17981  fdc235e0-7144-11e5-ba71-058fbc01cf0b                      7
# 17982  fdc23a68-7144-11e5-ba71-058fbc01cf0b                      1
# 17983  fdc23ba8-7144-11e5-ba71-058fbc01cf0b                     20
# 17984  fdc23e96-7144-11e5-ba71-058fbc01cf0b                      4
# 17985  fdc2417a-7144-11e5-ba71-058fbc01cf0b                      6
#
#        Mean ITI (days) Mean ITI (minutes)  Median ITI (days)  \
# 17981         0.009408        13.54722222           0.004786
# 17982              NaN            #VALUE!                NaN
# 17983         0.004957        7.137719299           0.004201
# 17984         0.002948        4.244444444           0.002778
# 17985         0.004012        5.776666648           0.003032
#
#       Median ITI (minutes)  Time diff between first and last game (days)  \
# 17981          6.891666669                                      0.056447
# ...

# %%
dog_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17986 entries, 0 to 17985
# Data columns (total 32 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Dog ID                                           17986 non-null  object
#  1   Total Tests Completed                            17986 non-null  int64
#  2   Mean ITI (days)                                  16718 non-null  float64
#  3   Mean ITI (minutes)                               17986 non-null  object
#  4   Median ITI (days)                                16718 non-null  float64
#  5   Median ITI (minutes)                             17986 non-null  object
#  6   Time diff between first and last game (days)     17986 non-null  float64
#  7   Time diff between first and last game (minutes)  17986 non-null  float64
#  8   User ID                                          17985 non-null  object
# ...
